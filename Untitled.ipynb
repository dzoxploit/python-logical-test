# %% [markdown]
# <a href="https://colab.research.google.com/github/dzoxploit/python-logical-test/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# !pip install six
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
col_names = ['color', 'height', 'width', 'label']
# load dataset
pima = pd.read_excel("datapakaiancuy.xlsx", header=None, names=col_names)
pima.values.tolist()
# Out:
# [['grey', 70, 170, 'hoodie'],
#  ['blue', 150, 80, 'celana'],
#  ['green', 30, 20, 'tshirt'],
#  ['black', 40, 30, 'tshirt'],
#  ['white', 120, 70, 'celana'],
#  ['red', 80, 180, 'hoodie'],
#  ['yellow', 140, 70, 'celana'],
#  ['orange', 50, 40, 'tshirt'],
#  ['blue ', 80, 185, 'hoodie'],
#  ['purple', 50, 40, 'tshirt']]

# %%
pima.head()
# Out:
#    color  height  width   label
# 0   grey      70    170  hoodie
# 1   blue     150     80  celana
# 2  green      30     20  tshirt
# 3  black      40     30  tshirt
# 4  white     120     70  celana

# %%
#split dataset in features and target variable
feature_cols = ['height', 'width']
X = pima[feature_cols] # Features
y = pima.label # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Create Decision Tree classifier object
clf = DecisionTreeClassifier()

# Train Decision Tree classifier
clf = clf.fit(X_train, y_train)

# Get unique class labels from the target variable
class_names = list(set(y_train))

# Plot the decision tree
plt.figure(figsize=(10, 10))
plot_tree(clf, feature_names=feature_cols, class_names=class_names, filled=True, rounded=True)
plt.savefig('diabetes.png')
plt.show()

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
